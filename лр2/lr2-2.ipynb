# %%
import numpy as np
import pandas as pd
pd.set_option('display.max.columns', 100)
import pandasql as pds
# to draw pictures in jupyter notebook
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns
# we don't like warnings
# you can comment the following 2 lines if you'd like to
import warnings
warnings.filterwarnings('ignore')

# %%
user_usage = pd.read_csv("user_usage.csv")
user_device = pd.read_csv("user_device.csv")
android_devices = pd.read_csv("android_devices.csv")

# %%
user_usage.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792

# %%
user_device.head()
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3
# 2   22784    28473  android               5.1   SM-G903F            1
# 3   22785    15200      ios              10.2  iPhone7,2            3
# 4   22786    28239  android               6.0  ONE E1003            1

# %%
android_devices = android_devices.rename(index=str, columns={'Device': 'device'})
android_devices.head()
# Out:
#   Retail Branding Marketing Name    device                      Model
# 0             NaN            NaN    AD681H  Smartfren Andromax AD681H
# 1             NaN            NaN     FJL21                      FJL21
# 2             NaN            NaN       T31              Panasonic T31
# 3             NaN            NaN  hws7721g         MediaPad 7 Youth 2
# 4              3Q        OC1020A   OC1020A                    OC1020A

# %% [markdown]
# ### Merge using pandas

# %%
user_usage_and_user_device = pd.merge(user_usage, user_device[['use_id', 'device']], on='use_id')
user_usage_and_user_device.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#      device
# 0  GT-I9505
# 1  SM-G930F
# 2  SM-G930F
# 3     D2303
# 4  SM-G361F

# %%
user_usage_and_user_device_and_android_devices = pd.merge(user_usage_and_user_device, 
                                    android_devices[['Model', 'Retail Branding']], 
                                    left_on='device', right_on='Model').drop_duplicates()
user_usage_and_user_device_and_android_devices.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                    69.80                   14.70    25955.55   22801
# 2                   249.26                  253.22     1557.33   22875
# 3                   249.26                  253.22     1557.33   22876
# 4                    83.46                  114.06     3114.67   22880
#
#      device     Model Retail Branding
# 0  GT-I9505  GT-I9505         Samsung
# 1  GT-I9505  GT-I9505         Samsung
# 2  GT-I9505  GT-I9505         Samsung
# 3  GT-I9505  GT-I9505         Samsung
# 4  GT-I9505  GT-I9505         Samsung

# %%
user_usage_and_user_device_and_android_devices.groupby('Retail Branding').agg({
    "outgoing_mins_per_month": "mean",
    "outgoing_sms_per_month": "mean",
    "monthly_mb": "mean",
    "use_id": "count"
})
# Out:
#                  outgoing_mins_per_month  outgoing_sms_per_month  \
# Retail Branding
# HTC                           289.315789               97.678421
# Huawei                         81.526667                9.500000
# LGE                           111.530000               12.760000
# Lava                           60.650000              261.900000
# Lenovo                        215.920000               12.930000
# Motorola                       96.780000               68.844000
# OnePlus                       308.740000               51.772500
# Samsung                       196.975556               93.815354
# Sony                          143.703846               39.114615
# Vodafone                       42.750000               46.830000
# ZTE                            42.750000               46.830000
#
#                    monthly_mb  use_id
# Retail Branding
# HTC               7080.200000      19
# Huawei            1561.226667       3
# LGE               1557.330000       2
# Lava             12458.670000       2
# Lenovo            1557.330000       1
# Motorola          4195.424000       5
# OnePlus           8824.890000       4
# Samsung           3725.970707      99
# Sony              2715.352308      13
# Vodafone          5191.120000       1
# ZTE               5191.120000       1

# %% [markdown]
# ### Merge using pandasql

# %%
query = """
    SELECT uu.*, ud.device FROM user_usage AS uu
    JOIN user_device AS ud ON uu.use_id = ud.use_id
"""
user_usage_and_user_device_sql = pds.sqldf(query, {'user_usage': user_usage, 'user_device': user_device})
user_usage_and_user_device_sql.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#      device
# 0  GT-I9505
# 1  SM-G930F
# 2  SM-G930F
# 3     D2303
# 4  SM-G361F

# %%
query = """
    SELECT DISTINCT ud.*, ad.`Retail Branding` FROM user_usage_and_user_device AS ud
    JOIN android_devices AS ad ON ud.device = ad.Model
"""
user_usage_and_user_device_and_android_devices_sql = pds.sqldf(
    query, {'user_usage_and_user_device': user_usage_and_user_device_sql, 'android_devices': android_devices})
user_usage_and_user_device_and_android_devices_sql.head()
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#      device Retail Branding
# 0  GT-I9505         Samsung
# 1  SM-G930F         Samsung
# 2  SM-G930F         Samsung
# 3     D2303            Sony
# 4  SM-G361F         Samsung

# %%
query = """
    SELECT `Retail Branding`, 
           AVG(outgoing_mins_per_month) AS outgoing_mins_per_month, 
           AVG(outgoing_sms_per_month) AS outgoing_sms_per_month, 
           AVG(monthly_mb) AS monthly_mb,
           COUNT(use_id) AS use_id 
           FROM user_usage_and_user_device_and_android_devices
    GROUP BY `Retail Branding`
"""
pds.sqldf(
    query, {'user_usage_and_user_device_and_android_devices': user_usage_and_user_device_and_android_devices_sql})
# Out:
#    Retail Branding  outgoing_mins_per_month  outgoing_sms_per_month  \
# 0              HTC               289.315789               97.678421
# 1           Huawei                81.526667                9.500000
# 2              LGE               111.530000               12.760000
# 3             Lava                60.650000              261.900000
# 4           Lenovo               215.920000               12.930000
# 5         Motorola                96.780000               68.844000
# 6          OnePlus               308.740000               51.772500
# 7          Samsung               196.975556               93.815354
# 8             Sony               143.703846               39.114615
# 9         Vodafone                42.750000               46.830000
# 10             ZTE                42.750000               46.830000
#
#       monthly_mb  use_id
# 0    7080.200000      19
# 1    1561.226667       3
# 2    1557.330000       2
# 3   12458.670000       2
# 4    1557.330000       1
# 5    4195.424000       5
# 6    8824.890000       4
# 7    3725.970707      99
# 8    2715.352308      13
# 9    5191.120000       1
# 10   5191.120000       1
